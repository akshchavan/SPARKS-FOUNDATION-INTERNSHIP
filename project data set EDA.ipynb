# %%
import numpy as np
import pandas as pd
import matplotlib as mlt
from matplotlib import pyplot as plt

# %%
import pandas as pd
hice=pd.read_csv('C:\\Users\\Akshay\\final project data.csv')

# %%
hice
# Out:
#                           email_id  age gender  like_your_work  \
# 0        vishal.ambala46@gmail.com   24    Male            Yes
# 1         ladheshubham15@gmail.com   22    Male            Yes
# 2          siddeshrs.a99@gmail.com   53    Male            Yes
# 3       pranav.sawant12@gmail.com    27    Male            Yes
# 4       nikhildevenpalli@gmail.com   26    Male            Yes
# 5            Sayar.kadam@gmail.con   25  Female            Yes
# 6           jumboraj1605@gmail.com   29    Male             No
# 7             saurisen33@gmail.com   23    Male            Yes
# 8          Pradipsanap03@gmail.com   24    Male            Yes
# 9            pbhalekar74@gmail.com   22    Male            Yes
# 10     Kamble.vaibhav24@gmail.com    35    Male            Yes
# 11     lakkabathinirohit@gmail.com   23    Male            Yes
# 12           gkondvilkar@gmail.com   25    Male            Yes
# 13        kulkarniuma909@gmail.com   23  Female            Yes
# ...

# %%
type(hice)
# Out:
# pandas.core.frame.DataFrame

# %%
age=hice['age']

# %%
age
# Out:
# 0     24
# 1     22
# 2     53
# 3     27
# 4     26
# 5     25
# 6     29
# 7     23
# 8     24
# 9     22
# 10    35
# 11    23
# 12    25
# 13    23
# 14    45
# 15    24
# 16    23
# 17    22
# Name: age, dtype: int64

# %%
print(hice.shape)
# Out:
# (18, 18)

# %%
print(hice.ndim)
# Out:
# 2

# %%
print(hice.size)
# Out:
# 324

# %%
print(type(hice))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
age.min()
# Out:
# 22

# %%
age.max()
# Out:
# 53

# %%
hice.iloc[[hice['age'].argmax()]]
# Out:
#                   email_id  age gender  like_your_work  \
# 2  siddeshrs.a99@gmail.com   53    Male            Yes
#
#   happy_with_your_work_environment satisfied_with_your_salaries  \
# 2                              Yes                          Yes
#
#   Did_you_feel_stressful_while_working work_more_hours night_shift  \
# 2                                  Yes           Maybe          No
#
#   stressful_in_team_work happy_with_the_facilities paid_on_time  \
# 2                     No                       Yes          Yes
#
#    working_years working_moto            expectation's_from_your_company  \
# 2           30.0         Both  To understand from employee point of view
#
#   shift_from_any_company getting_bonus  \
# 2                     No           Yes
#
#   are_you_planning_to_leave_your_job?(why)
# 2                                       No

# %%
hice.iloc[[hice['age'].argmin()]]
# Out:
#                    email_id  age gender  like_your_work  \
# 1  ladheshubham15@gmail.com   22    Male            Yes
#
#   happy_with_your_work_environment satisfied_with_your_salaries  \
# 1                              Yes                          Yes
#
#   Did_you_feel_stressful_while_working work_more_hours night_shift  \
# 1                                   No             Yes         Yes
#
#   stressful_in_team_work happy_with_the_facilities paid_on_time  \
# 1                     No                       Yes          Yes
#
#    working_years       working_moto expectation's_from_your_company  \
# 1            0.7  Quality Assurance    Already they are giving lot.
#
#   shift_from_any_company getting_bonus  \
# 1                     No           Yes
#
#   are_you_planning_to_leave_your_job?(why)
# 1                                       No

# %%
likelyhood = hice['like_your_work'].count()

# %%
likelyhood
# Out:
# 18

# %%
a=hice.sort_values('age').head()
print(a)
# Out:
#                        email_id  age gender  like_your_work  \
# 17      hadkevikrant@gmail.com    22    Male            Yes
# 1      ladheshubham15@gmail.com   22    Male            Yes
# 9         pbhalekar74@gmail.com   22    Male            Yes
# 13     kulkarniuma909@gmail.com   23  Female            Yes
# 11  lakkabathinirohit@gmail.com   23    Male            Yes
#
#    happy_with_your_work_environment satisfied_with_your_salaries  \
# 17                              Yes                          Yes
# 1                               Yes                          Yes
# 9                               Yes                           No
# 13                              Yes                           No
# 11                              Yes                           No
#
#    Did_you_feel_stressful_while_working work_more_hours night_shift  \
# 17                                  Yes             Yes         Yes
# 1                                    No             Yes         Yes
# ...

# %%
a=hice.sort_values('age').tail()
print(a)
# Out:
#                        email_id  age gender  like_your_work  \
# 3    pranav.sawant12@gmail.com    27    Male            Yes
# 6        jumboraj1605@gmail.com   29    Male             No
# 10  Kamble.vaibhav24@gmail.com    35    Male            Yes
# 14     Babblikjansexy@gmail.com   45  Female            Yes
# 2       siddeshrs.a99@gmail.com   53    Male            Yes
#
#    happy_with_your_work_environment satisfied_with_your_salaries  \
# 3                               Yes                           No
# 6                             Maybe                          Yes
# 10                              Yes                          Yes
# 14                              Yes                          Yes
# 2                               Yes                          Yes
#
#    Did_you_feel_stressful_while_working work_more_hours night_shift  \
# 3                                   Yes              No          No
# 6                                 Maybe              No          No
# ...

# %%
hice.isna()
# Out:
#     email_id    age  gender   like_your_work  \
# 0      False  False    False           False
# 1      False  False    False           False
# 2      False  False    False           False
# 3      False  False    False           False
# 4      False  False    False           False
# 5      False  False    False           False
# 6      False  False    False           False
# 7      False  False    False           False
# 8      False  False    False           False
# 9      False  False    False           False
# 10     False  False    False           False
# 11     False  False    False           False
# 12     False  False    False           False
# 13     False  False    False           False
# 14     False  False    False           False
# 15     False  False    False           False
# 16     False  False    False           False
# 17     False  False    False           False
#
#     happy_with_your_work_environment  satisfied_with_your_salaries  \
# ...

# %%
a=hice.groupby('age')
print(a.get_group(22))
# Out:
#                     email_id  age gender  like_your_work  \
# 1   ladheshubham15@gmail.com   22    Male            Yes
# 9      pbhalekar74@gmail.com   22    Male            Yes
# 17   hadkevikrant@gmail.com    22    Male            Yes
#
#    happy_with_your_work_environment satisfied_with_your_salaries  \
# 1                               Yes                          Yes
# 9                               Yes                           No
# 17                              Yes                          Yes
#
#    Did_you_feel_stressful_while_working work_more_hours night_shift  \
# 1                                    No             Yes         Yes
# 9                                    No              No         Yes
# 17                                  Yes             Yes         Yes
#
#    stressful_in_team_work happy_with_the_facilities paid_on_time  \
# 1                      No                       Yes          Yes
# ...

# %%
hice[hice['age']>30]
# Out:
#                        email_id  age gender  like_your_work  \
# 2       siddeshrs.a99@gmail.com   53    Male            Yes
# 10  Kamble.vaibhav24@gmail.com    35    Male            Yes
# 14     Babblikjansexy@gmail.com   45  Female            Yes
#
#    happy_with_your_work_environment satisfied_with_your_salaries  \
# 2                               Yes                          Yes
# 10                              Yes                          Yes
# 14                              Yes                          Yes
#
#    Did_you_feel_stressful_while_working work_more_hours night_shift  \
# 2                                   Yes           Maybe          No
# 10                                   No              No          No
# 14                                Maybe             Yes          No
#
#    stressful_in_team_work happy_with_the_facilities paid_on_time  \
# 2                      No                       Yes          Yes
# ...

# %%
a=hice.groupby('night_shift')
print(a.get_group('No'))
# Out:
#                           email_id  age gender  like_your_work  \
# 2          siddeshrs.a99@gmail.com   53    Male            Yes
# 3       pranav.sawant12@gmail.com    27    Male            Yes
# 4       nikhildevenpalli@gmail.com   26    Male            Yes
# 5            Sayar.kadam@gmail.con   25  Female            Yes
# 6           jumboraj1605@gmail.com   29    Male             No
# 8          Pradipsanap03@gmail.com   24    Male            Yes
# 10     Kamble.vaibhav24@gmail.com    35    Male            Yes
# 11     lakkabathinirohit@gmail.com   23    Male            Yes
# 14        Babblikjansexy@gmail.com   45  Female            Yes
# 15  shubhamchaudhari2344@gmail.com   24    Male            Yes
# 16      renukaghongate48@gmail.com   23  Female             No
#
#    happy_with_your_work_environment satisfied_with_your_salaries  \
# 2                               Yes                          Yes
# 3                               Yes                           No
# ...

# %%
a=hice.groupby('happy_with_the_facilities')
print(a.get_group('Yes'))
# Out:
#                           email_id  age gender  like_your_work  \
# 1         ladheshubham15@gmail.com   22    Male            Yes
# 2          siddeshrs.a99@gmail.com   53    Male            Yes
# 3       pranav.sawant12@gmail.com    27    Male            Yes
# 4       nikhildevenpalli@gmail.com   26    Male            Yes
# 5            Sayar.kadam@gmail.con   25  Female            Yes
# 10     Kamble.vaibhav24@gmail.com    35    Male            Yes
# 12           gkondvilkar@gmail.com   25    Male            Yes
# 13        kulkarniuma909@gmail.com   23  Female            Yes
# 14        Babblikjansexy@gmail.com   45  Female            Yes
# 15  shubhamchaudhari2344@gmail.com   24    Male            Yes
# 16      renukaghongate48@gmail.com   23  Female             No
# 17         hadkevikrant@gmail.com    22    Male            Yes
#
#    happy_with_your_work_environment satisfied_with_your_salaries  \
# 1                               Yes                          Yes
# ...

# %%
hice[hice['working_years']<0.8]
# Out:
#                           email_id  age gender  like_your_work  \
# 1         ladheshubham15@gmail.com   22    Male            Yes
# 9            pbhalekar74@gmail.com   22    Male            Yes
# 15  shubhamchaudhari2344@gmail.com   24    Male            Yes
#
#    happy_with_your_work_environment satisfied_with_your_salaries  \
# 1                               Yes                          Yes
# 9                               Yes                           No
# 15                              Yes                           No
#
#    Did_you_feel_stressful_while_working work_more_hours night_shift  \
# 1                                    No             Yes         Yes
# 9                                    No              No         Yes
# 15                                   No           Maybe          No
#
#    stressful_in_team_work happy_with_the_facilities paid_on_time  \
# 1                      No                       Yes          Yes
# ...

# %%
hice[hice['working_years']>10]
# Out:
#                   email_id  age gender  like_your_work  \
# 2  siddeshrs.a99@gmail.com   53    Male            Yes
#
#   happy_with_your_work_environment satisfied_with_your_salaries  \
# 2                              Yes                          Yes
#
#   Did_you_feel_stressful_while_working work_more_hours night_shift  \
# 2                                  Yes           Maybe          No
#
#   stressful_in_team_work happy_with_the_facilities paid_on_time  \
# 2                     No                       Yes          Yes
#
#    working_years working_moto            expectation's_from_your_company  \
# 2           30.0         Both  To understand from employee point of view
#
#   shift_from_any_company getting_bonus  \
# 2                     No           Yes
#
#   are_you_planning_to_leave_your_job?(why)
# 2                                       No
